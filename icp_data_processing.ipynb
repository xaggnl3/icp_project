# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('icp_data.csv', encoding='ISO-8859-1', sep=',')
# Out:
# /Users/mengxiangyong/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.rename(columns={'hosp':'num_patients'},inplace=True)

# %%
df.rename(columns={'tx_pos':'positive_rate','tx_incid':'total_positive_rate','TO':'Hospital_occupancy_rate','R':'Virus_infectivity'},inplace=True)

# %%
df.rename(columns={'rea':'num_seriously_ill_patients','rad':'num_cure','dchosp':'num_deaths','incid_dchosp':'num_deaths_24h','incid_rea':'num_seriously_ill_patients_24h','incid_rad':'num_cure_24h','pos':'positive_num','pos_7j':'positive_num_7days'},inplace=True)

# %%
outputpath='/Users/mengxiangyong/Documents/ICP_Code/fr_data.csv'  # set a path for this csv and the name of this csv
df.to_csv(outputpath,sep=',',index=True, index_label="id")

# %%
df = pd.read_csv('fr_data.csv', encoding='ISO-8859-1', sep=',')
# Out:
# /Users/mengxiangyong/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#           id department       date  region label of department  \
# 0          0          1  2020/3/18      84                 Ain
# 1          1          1  2020/3/19      84                 Ain
# 2          2          1  2020/3/20      84                 Ain
# 3          3          1  2020/3/21      84                 Ain
# 4          4          1  2020/3/22      84                 Ain
# ...      ...        ...        ...     ...                 ...
# 41001  41001        976  2021/4/23       6             Mayotte
# 41002  41002        976  2021/4/24       6             Mayotte
# 41003  41003        976  2021/4/25       6             Mayotte
# 41004  41004        976  2021/4/26       6             Mayotte
# 41005  41005        976  2021/4/27       6             Mayotte
#
#                label of region  positive  total_positive_rate  \
# 0      Auvergne et Rh_ne-Alpes       NaN                  NaN
# 1      Auvergne et Rh_ne-Alpes       NaN                  NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'department', 'date', 'region', 'label of department',
#        'label of region', 'positive', 'total_positive_rate',
#        'Hospital_occupancy_rate', 'Virus_infectivity', 'num_patients',
#        'num_seriously_ill_patients', 'num_cure', 'num_deaths', 'reg_rea',
#        'incid_hosp', 'num_seriously_ill_patients_24h', 'num_cure_24h',
#        'num_deaths_24h', 'reg_incid_rea', 'positive_num', 'positive_num_7days',
#        'cv_dose1'],
#       dtype='object')
